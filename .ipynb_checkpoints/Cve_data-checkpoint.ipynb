# %%
先將前面def的block都跑過
1、根據cve編號抓網頁內文(會存檔)
2、再將檔名放到block2中進行chatgpt

# %%
# 日期格式轉換1(可能不須要了)
import openpyxl
import calendar
def changeDate():
    filename="C:\\Users\\111\\Desktop\\CveExample20230515_WellDone.xlsx"
    from_which_row=2#從第幾row開始爬，通常從2開始
    wb =openpyxl.load_workbook(filename)
    keyword=['health','medical','cloud','bluetooth','pii','phi','ephi','infusion pump']
    # keyword=['ephi']
    for page_name in keyword:
        ws = wb[page_name]
        date=[]
        Q1=[]
        date_str=''
        for col in ws.iter_cols(min_col=2, max_col=2, min_row=from_which_row):
            for cell in col:
                date_str=str(cell.value)
                year = date_str[:4]
                month = date_str[4:6]
                day = date_str[6:]
                date_str='中華民國'+(year-1911)+'年'+month+'月'+day+'日'
                cell.value=date_str
    wb.save(filename)
    print("日期格式轉換 完成!")

# changeDate()

# %%
#  日期格式轉換2
import datetime
def changeCveDate(date_str):
    # 解析原始日期
    date = datetime.datetime.strptime(date_str, "%m/%d/%Y")

    # 提取年、月、日
    year = str(date.year - 1911).zfill(2)
    month = str(date.month).zfill(2)
    day = str(date.day).zfill(2)
    # 新的日期格式
    new_date_str = "中華民國{}年{}月{}日".format(year, month, day)
    return new_date_str
# 顯示結果

# =============測試用==================
# new_date_str=changeCveDate("03/21/2013")
# print(new_date_str)

# %%
# 抓風險跟日期的
import re
import datetime
import requests
import openpyxl#寫入檔案
from bs4 import BeautifulSoup
import openpyxl
import openai
import time
import pickle
#目標:抓到機構名稱+basescore存成一格

def getRiskRating(Cve_number_array):
    for Cve_number in Cve_number_array:
        print("Cve_number=",Cve_number)
        rate1=''
        rate2=''
        Rate=''
        nvdDate=''
        ratingUrl="https://nvd.nist.gov/vuln/detail/"+Cve_number
        response3 = requests.get(ratingUrl)
        if response3.status_code == 200:
            print('rating Success!')
            soup3 = BeautifulSoup(response3.text, 'html.parser')
            # 找到目標節點
            target_nodes = soup3.find_all('div', class_='col-lg-9 col-sm-6')
            span_nodes = soup3.find_all('span', class_='severityDetail')
            nvdDate_a=soup3.find('span', attrs={'data-testid': 'vuln-published-on'}).text.strip()
            nvdDate=changeCveDate(nvdDate_a)
            print("nvdDate=",nvdDate)
            # 提取每個節點中的文字___機構
            count=0
            for node1 in target_nodes:
                count=count+1
                if count==1:
                    rate1 = node1.get_text().strip()
                elif count==2:
                    rate2 = node1.get_text().strip()
                else :
                    break
            count=0       
            for node2 in span_nodes:
                count=count+1
                if count==1:
                    rate1 += "\n  Base Score: "+node2.get_text().strip()
#                     print(rate1)
                elif count==2:
                    rate2 += "\n  Base Score: "+node2.get_text().strip()
#                     print(rate2)
                else :
                    break
            Rate=rate1+ "\n"+rate2
#             print(Rate)
            rating_array.append(Rate)
            nvdDate_array.append(nvdDate)
#=================測試用========================    
# cve_number_array=['CVE-2023-28846','CVE-2023-25931']
# rating_array=[]
# nvdDate_array=[]
# getRiskRating(cve_number_array)
# for rate in rating_array:
#     print("rate=",rate)
# for nvdDate in nvdDate_array:
#     print("nvdDate=",nvdDate)    

# getRiskRating(cve_number_array)#去別的頁面抓Rating number
# print("done")

# %%
#根據cve編號抓網頁內文
import re
import datetime
import requests
import openpyxl#寫入檔案
from bs4 import BeautifulSoup
import openpyxl
import openai
import time
import pickle

wb = openpyxl.Workbook()
#========================       function       =========================
def searchWeb(cve_number):
    url_Web="https://cve.mitre.org/cgi-bin/cvename.cgi?name="+cve_number
    response = requests.get(url_Web)
    if response.status_code == 200:
        print('網頁內容Success!')
        soup2 = BeautifulSoup(response.text, 'html.parser')
        table_div = soup2.find('div', {'id': 'GeneratedTable'})
        tr_list = table_div.find_all('tr')
# =============第二個tr+第一個td_cve編號=====================
        td_list = tr_list[1].find_all('td')  # 找到第4個tr節點中所有的td節點
        cve_title = td_list[0].text.strip()  # 獲取第一個td節點的文字內容
# =============第四個tr_description=================
        description = tr_list[3].text.strip()
# =============第七個tr_reference===================
        reference = tr_list[6].text.strip()
# =============第十個tr+第一個td_date===================
        date=tr_list[10].find('b').text
        link="https://cve.mitre.org/cgi-bin/cvename.cgi?name="+cve_title
        return cve_title,date,description,reference,link
    
    else:
        print('Failed with status code:', response.status_code)
        

# 發送HTTP GET請求，獲取網頁內容
def firstPageSearch(searchKeyword):
    url = 'https://cve.mitre.org/cgi-bin/cvekey.cgi?keyword='+searchKeyword
    response = requests.get(url)
    if response.status_code == 200:
        print('搜尋頁面Success!')
        soup = BeautifulSoup(response.text, 'html.parser')
        table_div = soup.find('div', {'id': 'TableWithRules'})
        titles = []
        for a in table_div.find_all('a'):
            temp=searchWeb(a.text)
            if "CVE-2023" not in temp[0]:#篩選只要2023、2022的
                break
            cve_number_array.append(temp[0])
            date_array.append(temp[1])
            description_array.append(temp[2])
            reference_array.append(temp[3])
            link_array.append(temp[4])
    else:
        print('Failed with status code:', response.status_code)
# =========================主程式====================
# keyword=['health','medical device','cloud','bluetooth','pii','phi','ephi','infusion pump']
keyword=['infusion pump']
for page_name in keyword:
    ws = wb.create_sheet(page_name)
    # 先寫入檔案的表頭
    ws['A1'] = 'Cve Number'
    ws['B1'] = 'Cve Date'
    ws['C1'] = 'Description'
    ws['D1'] = 'Reference'
    ws['E1'] = 'Link'
    ws['H1'] ='Rating'
    #儲存的array
    cve_number_array = []
    description_array = []
    reference_array = []
    date_array=[]
    link_array=[]
    rating_array=[]
    nvdDate_array=[]
    firstPageSearch(page_name)#回傳前五欄cve_title,date,description,reference,link
    getRiskRating(cve_number_array)#去別的頁面抓Rating number，以及NVD收錄的日期
    for row in zip(cve_number_array, date_array, description_array,reference_array,link_array):
        ws.append(row)
    for i in range(len(rating_array)):
        cell = ws.cell(row=i+2, column=8) # row=i+2 表示從第2列開始，column=6 表示第6欄
        cell.value = rating_array[i]
    for i in range(len(nvdDate_array)):
        cell = ws.cell(row=i+2, column=2) # 
        cell.value = nvdDate_array[i]
#存檔
print("現在存檔")
a=str(datetime.date.today().strftime('%Y%m%d')+"_"+datetime.datetime.now().strftime("%H%M%S")+".xlsx")
filename=r"C:\Users\111\Desktop\CveExample"+a
# print(filename)
wb.save(filename)#檔案存在哪
print("done")
# Out:
# 搜尋頁面Success!
# 網頁內容Success!
# 網頁內容Success!
# Cve_number= CVE-2023-0888
# rating Success!
# nvdDate= 中華民國112年03月13日
# 現在存檔
# done

# %%
#  =================================         chatgpt          ============================================
import re
import datetime
import requests
import openpyxl#寫入檔案
from bs4 import BeautifulSoup
import openpyxl
import openai
import time
import csv
openai.api_key = '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'
# 開啟Excel檔案
filename="C:\\Users\\111\\Desktop\\CveExample20230520_124404.xlsx"
from_which_row=2#從第幾row開始爬，通常從2開始
def Q1ByGpt(description):
    #將內文用chatgpt摘要
    print("現在chatgpt1")
    st=description+"請根據上文用繁體中文做摘要"
    print(st)
    response_gpt = openai.Completion.create(
        model="text-davinci-003",
        prompt=st,
        max_tokens=1800,
        temperature=0.5,
    )
    completed_text = response_gpt.choices[0].text.strip()
    print(completed_text)
    return completed_text
def Q2ByGpt(description):
 #將內文用chatgpt摘要
    print("現在chatgpt2")
    st=description+"以上描述提及哪些設備或軟體並用中文簡略說明是哪種設備，請用1、2、3、等列點式，直接列點即可，若無請回答None"
    print(st)
    response_gpt2 = openai.Completion.create(
        model="text-davinci-003",
        prompt=st,
        max_tokens=1700,
        temperature=0.5,
    )
    completed2_text = response_gpt2["choices"][0].text.strip()
    print (completed2_text)
    return completed2_text

try:
    wb = openpyxl.load_workbook(filename)
    # keyword=['health','medical device','cloud','bluetooth','pii','phi','ephi','infusion pump']
    keyword=['infusion pump']
    Q1=[]
    Q2=[]
    for page_name in keyword:
        ws = wb[page_name]
        Q1.clear()
        Q2.clear()
        ws['F1'] = '中文摘要'
        ws['G1'] = '設備or軟體'
        ws['H1'] ='Check point'
        
        # 使用 iter_cols() 方法遍歷 C 欄的所有儲存格，將其丟給chatgpt處理，最後存到q1、q2
        for col in ws.iter_cols(min_col=3, max_col=3, min_row=from_which_row):
            for cell in col:
                print("now,chatgpt")
    #             print(cell.value)
                Q1.append(Q1ByGpt(cell.value))
                Q2.append(Q2ByGpt(cell.value))
        for i in range(len(Q1)):
            cell = ws.cell(row=i+from_which_row, column=6) # row=i+2 表示從第2列開始，column=6 表示第6欄
            cell.value = Q1[i]
        for i in range(len(Q2)):
            cell = ws.cell(row=i+from_which_row, column=7) # row=i+2 表示從第2列開始，column=7 表示第7欄
            cell.value = Q2[i]
            
            
    # 儲存Excel檔案
    wb.save(filename)
    print("done")
    
except Exception as e:
    # 第一次發生錯誤時的處理方式
    print('程式發生錯誤:', e)
    for i in range(len(Q1)):
        cell = ws.cell(row=i+from_which_row, column=6) # row=1 表示從第一列開始，column=5 表示第五欄
        cell.value = Q1[i]
    for i in range(len(Q2)):
        cell = ws.cell(row=i+from_which_row, column=7) # row=1 表示從第一列開始，column=5 表示第五欄
        cell.value = Q2[i]
    # 將已經爬取的資料儲存到 Excel 檔案
    wb.save(filename)
# Out:
# now,chatgpt
# 現在chatgpt1
# An improper neutralization of directives in dynamically evaluated code vulnerability in the WiFi Battery embedded web server in versions L90/U70 and L92/U92 can be used to gain administrative access to the WiFi communication module. An authenticated user, having access to both the medical device WiFi network (such as a biomedical engineering staff member) and the specific B.Braun Battery Pack SP with WiFi web server credentials, could get administrative (root) access on the infusion pump communication module. This could be used as a vector to start further attacks請根據上文用繁體中文做摘要
# 在L90/U70和L92/U92版本的WiFi電池嵌入式網頁伺服器中，對指令的不當中和動態評估代碼漏洞，可以用於獲得WiFi通信模組的管理權限。擁有醫療設備WiFi網路（如生物醫學工程人員）和特定B.Braun電池包SP的WiFi網頁伺服器憑證的認證用戶，可以在輸注泵通信模組上獲得管理（root）權限。這可以用作開始進一步攻擊的管道。
# 現在chatgpt2
# An improper neutralization of directives in dynamically evaluated code vulnerability in the WiFi Battery embedded web server in versions L90/U70 and L92/U92 can be used to gain administrative access to the WiFi communication module. An authenticated user, having access to both the medical device WiFi network (such as a biomedical engineering staff member) and the specific B.Braun Battery Pack SP with WiFi web server credentials, could get administrative (root) access on the infusion pump communication module. This could be used as a vector to start further attacks以上描述提及哪些設備或軟體並用中文簡略說明是哪種設備，請用1、2、3、等列點式，直接列點即可，若無請回答None
# 1. WiFi Battery 嵌入式網頁伺服器：一種可以讓使用者透過網頁連接的嵌入式伺服器
# 2. L90/U70 和 L92/U92：B.Braun 電池組 SP 的 WiFi 網頁伺服器版本
# 3. 醫療設備 WiFi 網路：授權的使用者可以連接的 WiFi 網路，例如生物醫學工程人員
# None
# done

# %%
#用來現有資料的main(不需要跑這邊)

import openpyxl

# 開啟 Excel 檔案
filename = 'C:\\Users\\111\\Desktop\\CveExample20230515_WellDone_2023.xlsx'
wb = openpyxl.load_workbook(filename)
# keyword=['health','medical','cloud','bluetooth','pii','phi','ephi','infusion pump']
keyword=['health','medical','cloud','bluetooth','infusion pump']
# keyword=['infusion pump']
for page_name in keyword:
    ws = wb[page_name]
    rating_array=[]#
    nvdDate_array=[]#
    # 讀取 A 欄的儲存格值
    ws['H1'] ='Rating'
    ws['B1']='Cve Date'
    values = []
    for cell in ws['A'][1:]:
        cell_value = cell.value
        print(cell_value)
        values.append(cell_value)
    # 顯示讀取結果
    print("len(values)=",len(values))
    getRiskRating(values)
    for i in range(len(rating_array)):
        cell = ws.cell(row=i+2, column=8) # row=1 表示從第一列開始，column=5 表示第五欄
        cell.value = rating_array[i]
#         print("1:",cell.value)
    for i in range(len(nvdDate_array)):
        cell = ws.cell(row=i+2, column=2) # row=1 表示從第一列開始，column=5 表示第五欄
        cell.value = nvdDate_array[i]
#         print("2:",cell.value)
    print("done")

# 關閉 Excel 檔案
wb.save(filename)
wb.close()
# Out:
# CVE-2023-25931
# CVE-2023-1156
# CVE-2023-28846
# CVE-2023-1180
# CVE-2023-1254
# CVE-2023-1253
# CVE-2023-21993
# CVE-2023-21926
# CVE-2023-21925
# CVE-2023-21924
# CVE-2023-21923
# CVE-2023-21922
# CVE-2023-21921
# CVE-2023-1767
# CVE-2023-1802
# len(values)= 15
# Cve_number= CVE-2023-25931
# rating Success!
# nvdDate= 中華民國112年03月01日
# Cve_number= CVE-2023-1156
# rating Success!
# nvdDate= 中華民國112年03月02日
# Cve_number= CVE-2023-28846
# rating Success!
# nvdDate= 中華民國112年03月30日
# Cve_number= CVE-2023-1180
# rating Success!
# nvdDate= 中華民國112年03月05日
# Cve_number= CVE-2023-1254
# rating Success!
# nvdDate= 中華民國112年03月07日
# Cve_number= CVE-2023-1253
# rating Success!
# nvdDate= 中華民國112年03月07日
# Cve_number= CVE-2023-21993
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-21926
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-21925
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-21924
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-21923
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-21922
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-21921
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-1767
# rating Success!
# nvdDate= 中華民國112年04月20日
# Cve_number= CVE-2023-1802
# rating Success!
# nvdDate= 中華民國112年04月06日
# done
# CVE-2023-0888
# CVE-2023-1151
# CVE-2023-1566
# len(values)= 3
# Cve_number= CVE-2023-0888
# rating Success!
# nvdDate= 中華民國112年03月13日
# Cve_number= CVE-2023-1151
# rating Success!
# nvdDate= 中華民國112年03月02日
# Cve_number= CVE-2023-1566
# rating Success!
# nvdDate= 中華民國112年03月22日
# done
# CVE-2023-0346
# CVE-2023-0347
# CVE-2023-1786
# CVE-2023-1998
# CVE-2023-20873
# CVE-2023-20903
# CVE-2023-22335
# CVE-2023-22336
# CVE-2023-22344
# CVE-2023-22916
# CVE-2023-25661
# CVE-2023-25722
# CVE-2023-25817
# CVE-2023-25818
# CVE-2023-26261
# CVE-2023-26290
# CVE-2023-26291
# CVE-2023-26292
# CVE-2023-26358
# CVE-2023-26482
# CVE-2023-27487
# CVE-2023-27488
# CVE-2023-27491
# CVE-2023-27492
# CVE-2023-27493
# CVE-2023-27496
# CVE-2023-27587
# CVE-2023-27588
# CVE-2023-27589
# CVE-2023-28140
# CVE-2023-28141
# CVE-2023-28142
# CVE-2023-28143
# CVE-2023-28432
# CVE-2023-28433
# CVE-2023-28434
# CVE-2023-28643
# CVE-2023-28644
# CVE-2023-28647
# CVE-2023-28833
# CVE-2023-28834
# CVE-2023-28835
# CVE-2023-28844
# CVE-2023-29010
# CVE-2023-30444
# CVE-2023-30610
# CVE-2023-30612
# len(values)= 47
# Cve_number= CVE-2023-0346
# rating Success!
# nvdDate= 中華民國112年03月13日
# Cve_number= CVE-2023-0347
# rating Success!
# nvdDate= 中華民國112年03月13日
# Cve_number= CVE-2023-1786
# rating Success!
# nvdDate= 中華民國112年04月26日
# Cve_number= CVE-2023-1998
# rating Success!
# nvdDate= 中華民國112年04月21日
# Cve_number= CVE-2023-20873
# rating Success!
# nvdDate= 中華民國112年04月20日
# Cve_number= CVE-2023-20903
# rating Success!
# nvdDate= 中華民國112年03月28日
# Cve_number= CVE-2023-22335
# rating Success!
# nvdDate= 中華民國112年03月05日
# Cve_number= CVE-2023-22336
# rating Success!
# nvdDate= 中華民國112年03月05日
# Cve_number= CVE-2023-22344
# rating Success!
# nvdDate= 中華民國112年03月05日
# Cve_number= CVE-2023-22916
# rating Success!
# nvdDate= 中華民國112年04月24日
# Cve_number= CVE-2023-25661
# rating Success!
# nvdDate= 中華民國112年03月27日
# Cve_number= CVE-2023-25722
# rating Success!
# nvdDate= 中華民國112年03月28日
# Cve_number= CVE-2023-25817
# rating Success!
# nvdDate= 中華民國112年03月27日
# Cve_number= CVE-2023-25818
# rating Success!
# nvdDate= 中華民國112年03月27日
# Cve_number= CVE-2023-26261
# rating Success!
# nvdDate= 中華民國112年03月08日
# Cve_number= CVE-2023-26290
# rating Success!
# nvdDate= 中華民國112年03月29日
# Cve_number= CVE-2023-26291
# rating Success!
# nvdDate= 中華民國112年03月29日
# Cve_number= CVE-2023-26292
# rating Success!
# nvdDate= 中華民國112年03月29日
# Cve_number= CVE-2023-26358
# rating Success!
# nvdDate= 中華民國112年03月22日
# Cve_number= CVE-2023-26482
# rating Success!
# nvdDate= 中華民國112年03月30日
# Cve_number= CVE-2023-27487
# rating Success!
# nvdDate= 中華民國112年04月04日
# Cve_number= CVE-2023-27488
# rating Success!
# nvdDate= 中華民國112年04月04日
# Cve_number= CVE-2023-27491
# rating Success!
# nvdDate= 中華民國112年04月04日
# Cve_number= CVE-2023-27492
# rating Success!
# nvdDate= 中華民國112年04月04日
# Cve_number= CVE-2023-27493
# rating Success!
# nvdDate= 中華民國112年04月04日
# Cve_number= CVE-2023-27496
# rating Success!
# nvdDate= 中華民國112年04月04日
# Cve_number= CVE-2023-27587
# rating Success!
# nvdDate= 中華民國112年03月13日
# Cve_number= CVE-2023-27588
# rating Success!
# nvdDate= 中華民國112年03月14日
# Cve_number= CVE-2023-27589
# rating Success!
# nvdDate= 中華民國112年03月14日
# Cve_number= CVE-2023-28140
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-28141
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-28142
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-28143
# rating Success!
# nvdDate= 中華民國112年04月18日
# Cve_number= CVE-2023-28432
# rating Success!
# nvdDate= 中華民國112年03月22日
# Cve_number= CVE-2023-28433
# rating Success!
# nvdDate= 中華民國112年03月22日
# Cve_number= CVE-2023-28434
# rating Success!
# nvdDate= 中華民國112年03月22日
# Cve_number= CVE-2023-28643
# rating Success!
# nvdDate= 中華民國112年03月30日
# Cve_number= CVE-2023-28644
# rating Success!
# nvdDate= 中華民國112年03月30日
# Cve_number= CVE-2023-28647
# rating Success!
# nvdDate= 中華民國112年03月30日
# Cve_number= CVE-2023-28833
# rating Success!
# nvdDate= 中華民國112年03月30日
# Cve_number= CVE-2023-28834
# rating Success!
# nvdDate= 中華民國112年04月03日
# Cve_number= CVE-2023-28835
# rating Success!
# nvdDate= 中華民國112年03月30日
# Cve_number= CVE-2023-28844
# rating Success!
# nvdDate= 中華民國112年03月31日
# Cve_number= CVE-2023-29010
# rating Success!
# nvdDate= 中華民國112年04月06日
# Cve_number= CVE-2023-30444
# rating Success!
# nvdDate= 中華民國112年04月27日
# Cve_number= CVE-2023-30610
# rating Success!
# nvdDate= 中華民國112年04月19日
# Cve_number= CVE-2023-30612
# rating Success!
# nvdDate= 中華民國112年04月19日
# done
# CVE-2023-23388
# CVE-2023-24871
# CVE-2023-21452
# CVE-2023-21457
# CVE-2023-23002
# CVE-2023-20980
# CVE-2023-20982
# CVE-2023-20987
# CVE-2023-20988
# CVE-2023-20992
# CVE-2023-21040
# CVE-2023-28866
# CVE-2023-0775
# CVE-2023-28464
# CVE-2023-26109
# CVE-2023-26110
# CVE-2023-1989
# CVE-2023-28227
# CVE-2023-31083
# CVE-2023-20869
# CVE-2023-20870
# len(values)= 21
# Cve_number= CVE-2023-23388
# rating Success!
# nvdDate= 中華民國112年03月14日
# Cve_number= CVE-2023-24871
# rating Success!
# nvdDate= 中華民國112年03月14日
# Cve_number= CVE-2023-21452
# rating Success!
# nvdDate= 中華民國112年03月16日
# Cve_number= CVE-2023-21457
# rating Success!
# nvdDate= 中華民國112年03月16日
# Cve_number= CVE-2023-23002
# rating Success!
# nvdDate= 中華民國112年03月01日
# Cve_number= CVE-2023-20980
# rating Success!
# nvdDate= 中華民國112年03月24日
# Cve_number= CVE-2023-20982
# rating Success!
# nvdDate= 中華民國112年03月24日
# Cve_number= CVE-2023-20987
# rating Success!
# nvdDate= 中華民國112年03月24日
# Cve_number= CVE-2023-20988
# rating Success!
# nvdDate= 中華民國112年03月24日
# Cve_number= CVE-2023-20992
# rating Success!
# nvdDate= 中華民國112年03月24日
# Cve_number= CVE-2023-21040
# rating Success!
# nvdDate= 中華民國112年03月24日
# Cve_number= CVE-2023-28866
# rating Success!
# nvdDate= 中華民國112年03月26日
# Cve_number= CVE-2023-0775
# rating Success!
# nvdDate= 中華民國112年03月28日
# Cve_number= CVE-2023-28464
# rating Success!
# nvdDate= 中華民國112年03月31日
# Cve_number= CVE-2023-26109
# rating Success!
# nvdDate= 中華民國112年03月09日
# Cve_number= CVE-2023-26110
# rating Success!
# nvdDate= 中華民國112年03月09日
# Cve_number= CVE-2023-1989
# rating Success!
# nvdDate= 中華民國112年04月11日
# Cve_number= CVE-2023-28227
# rating Success!
# nvdDate= 中華民國112年04月11日
# Cve_number= CVE-2023-31083
# rating Success!
# nvdDate= 中華民國112年04月24日
# Cve_number= CVE-2023-20869
# rating Success!
# nvdDate= 中華民國112年04月25日
# Cve_number= CVE-2023-20870
# rating Success!
# nvdDate= 中華民國112年04月25日
# done
# CVE-2023-0888
# len(values)= 1
# Cve_number= CVE-2023-0888
# rating Success!
# nvdDate= 中華民國112年03月13日
# done
